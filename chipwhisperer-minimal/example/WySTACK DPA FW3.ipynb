# %% [markdown]
# # Firmware 3: State Machine

# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWNANO'
VERSION = 'HARDWARE'

# %%
# %%capture
# %run "WYSTACK23 build.ipynb"

# %% [markdown]
# ## Get the master trace as an average

# %%
import numpy as np
avg_trace = np.average(trace_array, axis=0)

# %%
# %matplotlib inline
import matplotlib.pylab as plt
plt.figure(figsize=(10,6))
plt.plot(avg_trace, 'r')

# %%
# %matplotlib inline
import matplotlib.pylab as plt
plt.figure(figsize=(10,6))
plt.plot(avg_trace, 'r')

# %%
# %matplotlib inline
import matplotlib.pylab as plt
plt.figure(figsize=(10,6))
plt.plot(avg_trace, 'r')
